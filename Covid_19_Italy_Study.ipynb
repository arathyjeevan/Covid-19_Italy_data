# %% [markdown]
# <a href="https://colab.research.google.com/github/arathyjeevan/Covid-social-media-analysis/blob/master/Covid_19_Italy_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas.util.testing as tm
import os

# %%
url ="https://raw.githubusercontent.com/arathyjeevan/Covid-social-media-analysis/master/c19.csv"
data =pd.read_csv(url)
data.head()
# Out:
#    SNo                 Date Country  ...  Deaths TotalPositiveCases  TestsPerformed
# 0    0  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
# 1    1  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
# 2    2  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
# 3    3  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
# 4    4  2020-02-24T18:00:00     ITA  ...       0                 18             NaN
#
# [5 rows x 17 columns]

# %%
data.columns
data.tail()
# Out:
#        SNo                 Date  ... TotalPositiveCases  TestsPerformed
# 2788  2788  2020-07-05T17:00:00  ...               3094        180132.0
# 2789  2789  2020-07-05T17:00:00  ...              10285        237344.0
# 2790  2790  2020-07-05T17:00:00  ...               1447         67644.0
# 2791  2791  2020-07-05T17:00:00  ...               1196         14039.0
# 2792  2792  2020-07-05T17:00:00  ...              19326        422585.0
#
# [5 rows x 17 columns]

# %%
data.describe()
# Out:
#                SNo   RegionCode  ...  TotalPositiveCases  TestsPerformed
# count  2793.000000  2793.000000  ...         2793.000000     1638.000000
# mean   1396.000000    11.857143  ...         7654.104905   107103.777167
# std     806.413976     6.274922  ...        15680.871580   111274.492664
# min       0.000000     1.000000  ...            0.000000     3482.000000
# 25%     698.000000     7.000000  ...          580.000000    34905.500000
# 50%    1396.000000    12.000000  ...         2608.000000    65010.000000
# 75%    2094.000000    17.000000  ...         6701.000000   142043.000000
# max    2792.000000    22.000000  ...        94416.000000   647739.000000
#
# [8 rows x 14 columns]

# %%
data.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %% [markdown]
# # Data Visualization

# %%
sns.relplot(x="TotalPositiveCases",y="Recovered", data=data)

# %%
sns.pairplot(data)
